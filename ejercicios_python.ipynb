# %%
print("OK Matplotlib lista para usar")
# Out:
# OK Matplotlib lista para usar

# %%
# Mi primer programa - UPEC Python
nombre = "Estudiante UPEC"
carrera = "Ingeniería"
semestre = "Primero"
print(f"Hola, {nombre}!")
print(f"Carrera: {carrera}")
print(f"Semestre: {semestre}")
print("Tu ambiente esta listo para programar!")
# Out:
# Hola, Estudiante UPEC!
# Carrera: Ingeniería
# Semestre: Primero
# Tu ambiente esta listo para programar!

# %%
print("OK Pandas:", pd.__version__)
# Out:
# OK Pandas: 3.0.3

# %%
print("OK NumPy:", np.__version__)
# Out:
# OK NumPy: 2.4.6

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np
